# %%
# Matrix Factorization using Surprise SVD

# This notebook uses the Surprise library’s SVD implementation, which includes bias terms and regularization, similar to production recommender systems.

# %%
! pip install scikit-surprise
# Out:
# Requirement already satisfied: scikit-surprise in /Users/admin/Desktop/recommender-research/venv/lib/python3.12/site-packages (1.1.4)
# Requirement already satisfied: joblib>=1.2.0 in /Users/admin/Desktop/recommender-research/venv/lib/python3.12/site-packages (from scikit-surprise) (1.5.3)
# Requirement already satisfied: numpy>=1.19.5 in /Users/admin/Desktop/recommender-research/venv/lib/python3.12/site-packages (from scikit-surprise) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /Users/admin/Desktop/recommender-research/venv/lib/python3.12/site-packages (from scikit-surprise) (1.17.0)

# %%
import sys
sys.executable
# Out:
# '/Users/admin/Desktop/recommender-research/venv/bin/python3.12'

# %%
# !{sys.executable} -m pip uninstall -y numpy
# !{sys.executable} -m pip install "numpy<2.0"
# !{sys.executable} -m pip uninstall -y scikit-surprise
# !{sys.executable} -m pip install scikit-surprise
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Collecting numpy<2.0
#   Using cached numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl (13.7 MB)
# Installing collected packages: numpy
# Successfully installed numpy-1.26.4
# Found existing installation: scikit-surprise 1.1.4
# Uninstalling scikit-surprise-1.1.4:
#   Successfully uninstalled scikit-surprise-1.1.4
# Collecting scikit-surprise
#   Using cached scikit_surprise-1.1.4-cp312-cp312-macosx_15_0_arm64.whl
# Requirement already satisfied: joblib>=1.2.0 in /Users/admin/Desktop/recommender-research/venv/lib/python3.12/site-packages (from scikit-surprise) (1.5.3)
# Requirement already satisfied: numpy>=1.19.5 in /Users/admin/Desktop/recommender-research/venv/lib/python3.12/site-packages (from scikit-surprise) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /Users/admin/Desktop/recommender-research/venv/lib/python3.12/site-packages (from scikit-surprise) (1.17.0)
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.4

# %%
import numpy as np
np.__version__
# Out:
# '1.26.4'

# %%
import pandas as pd
import numpy as np

from surprise import SVD, Dataset, Reader
from surprise.model_selection import train_test_split
from surprise import accuracy

# %%
ratings = pd.read_csv("../data/ratings.csv")
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
reader = Reader(rating_scale=(0.5, 5.0))

data = Dataset.load_from_df(
    ratings[['userId', 'movieId', 'rating']],
    reader
)

# %%
trainset, testset = train_test_split(
    data,
    test_size=0.2,
    random_state=42
)

# %%
svd = SVD(
    n_factors=50,
    n_epochs=20,
    lr_all=0.005,
    reg_all=0.02,
    random_state=42
)

svd.fit(trainset)

# %%
predictions = svd.test(testset)

rmse_surprise = accuracy.rmse(predictions)
# Out:
# RMSE: 0.8775

# %%
rmse_global = 1.048841
rmse_movie = 0.982739
rmse_user_cf = 0.919100
rmse_item_cf = 0.901400

pd.DataFrame({
    "Model": [
        "Global Average",
        "Movie Average",
        "User-Based CF",
        "Item-Based CF",
        "Surprise SVD"
    ],
    "RMSE": [
        rmse_global,
        rmse_movie,
        rmse_user_cf,
        rmse_item_cf,
        rmse_surprise
    ]
})

## Why Surprise SVD Performs Best

# - Explicit modeling of user and item biases
# - Regularization prevents overfitting
# - Latent factor learning captures hidden preferences
# - Industry-standard implementation used in research and production
# Out:
#             Model      RMSE
# 0  Global Average  1.048841
# 1   Movie Average  0.982739
# 2   User-Based CF  0.919100
# 3   Item-Based CF  0.901400
# 4    Surprise SVD  0.877468
